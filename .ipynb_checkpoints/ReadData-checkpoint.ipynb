# %%
import os
import pandas as pd
import numpy as np
from PIL import Image

# %%
os.listdir("data/img_align_celeba/")
# Out:
# ['052628.jpg',
#  '110369.jpg',
#  '161590.jpg',
#  '065084.jpg',
#  '108526.jpg',
#  '045354.jpg',
#  '139923.jpg',
#  '091663.jpg',
#  '107615.jpg',
#  '003301.jpg',
#  '195377.jpg',
#  '150995.jpg',
#  '141640.jpg',
#  '118735.jpg',
#  '126803.jpg',
#  '192418.jpg',
#  '075297.jpg',
#  '171783.jpg',
#  '160856.jpg',
#  '151453.jpg',
#  '185164.jpg',
#  '013112.jpg',
#  '117406.jpg',
#  '081470.jpg',
#  '055147.jpg',
#  '043725.jpg',
#  '101264.jpg',
#  '097212.jpg',
#  '074189.jpg',
#  '193706.jpg',
#  '005770.jpg',
#  '147231.jpg',
#  '054259.jpg',
#  '148102.jpg',
#  '116718.jpg',
#  '141898.jpg',
#  '098121.jpg',
#  '109638.jpg',
#  '157022.jpg',
#  '015563.jpg',
#  '183515.jpg',
#  '087001.jpg',
#  '111077.jpg',
#  '053536.jpg',
#  '062933.jpg',
#  '088332.jpg',
#  '194069.jpg',
#  '158311.jpg',
#  '024966.jpg',
#  '047543.jpg',
#  '019359.jpg',
#  '093074.jpg',
#  '105002.jpg',
#  '001516.jpg',
#  '197560.jpg',
#  '143057.jpg',
#  '198653.jpg',
#  '189986.jpg',
# ...

# %%
im = Image.open("D:\Prototype\Bikesgray.jpg")
